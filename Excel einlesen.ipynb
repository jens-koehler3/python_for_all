# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
pd.read_excel('DB_Auszug_ROTCE_und_RSE_nachBsp2_CU38088 - Kopie.xlsx')
# Out:
#          ACCOUNT_NUMBER  CLASS_ID  CUSTOMER_NUMBER DETAIL_DELETION_INDICATOR  \
# 0     1       700076501      6049        710074951                         *
# 1     2       700076501      6049        710074951                         *
# 2     3       700076501      6050        710074951                         *
# 3     4       700076501      6049        710074951                         *
# 4     5       700076501      6050        710074951                         *
# 5     6       700076501      6049        710074951                         *
# 6     7       700076501      6049        710074951                         *
# 7     8       700076501      6049        710074951                         *
# 8     9       700076501      6050        710074951                         *
# 9    10       700076501      6049        710074951                         *
# 10   11       700076501      6049        710074951                         *
#
# ...
